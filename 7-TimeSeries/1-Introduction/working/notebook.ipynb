# %% [markdown]
# # Data Setup
#
# In this notebook, we demonstrate how to:
#
# setup time series data for this module
# visualize the data
# The data in this example is taken from the GEFCom2014 forecasting competition1. It consists of 3 years of hourly electricity load and temperature values between 2012 and 2014.
#
# 1Tao Hong, Pierre Pinson, Shu Fan, Hamidreza Zareipour, Alberto Troccoli and Rob J. Hyndman, "Probabilistic energy forecasting: Global Energy Forecasting Competition 2014 and beyond", International Journal of Forecasting, vol.32, no.3, pp 896-913, July-September, 2016.
#
# 1. Start by adding libraries that will help you load and visualize data:

# %%
import os
import matplotlib.pyplot as plt
from common.utils import load_data

# %% [markdown]
# Note, you are using the files from the included `common` folder which set up your environment and handle downloading the data.
#
# 2. Next, examine the data as a dataframe calling `load_data()` and `head()`:

# %%
data_dir = './data'
energy = load_data(data_dir)[['load']]
energy.head()
# Out:
# c:\Users\aminu\Documents\ArewaDS\ArewaDS-Machine-Learning-Assignments\7-TimeSeries\1-Introduction\working\common\utils.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   energy = energy.reindex(pd.date_range(min(energy['timestamp']),
#                        load
# 2012-01-01 00:00:00  2698.0
# 2012-01-01 01:00:00  2558.0
# 2012-01-01 02:00:00  2444.0
# 2012-01-01 03:00:00  2402.0
# 2012-01-01 04:00:00  2403.0

# %% [markdown]
# You can see that there are two columns representing date and load:
#
# 3. Now, plot the data calling plot():

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# 4. Now, plot the first week of July 2014, by providing it as input to the energy in [from date]: [to date] pattern:

# %%
energy['2014-07-01':'2014-07-07'].plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# A beautiful plot! Take a look at these plots and see if you can determine any of the characteristics listed above. What can we surmise by visualizing the data?
#
# **Answer**: The plots clearly shows a trend in the data. Also, it displays a consistent fluctuation (constant variance).
#
# In the next lesson, you will create an ARIMA model to create some forecasts.
